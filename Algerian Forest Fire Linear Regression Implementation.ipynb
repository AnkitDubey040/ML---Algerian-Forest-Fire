# %% [markdown]
# ![zomato](Wildfire-1.jpeg "Title")

# %% [markdown]
# ### Life cycle of Machine learning Project
# * Understanding the Problem Statement
# * Data Collection
# * Data Cleaning
# * Exploratory data analysis
# * Data Pre-Processing
# * Model Training
# * Choose best model

# %% [markdown]
# ### 1. Problem statement.
# * The dataset Comprises of two regions of Algeria, namely the Bejaia region located in the northeast of Algeria and the Sidi Bel-abbes region located in the northwest of Algeria.
#
# * If User can Predict that Algerian Forest Temperature on Input Features.
#
# * Prediction result can be used for Forest Fire Situation Tackers & Make Correct Preventions to Avoid it in future.

# %% [markdown]
# ### 2. Data Collection.
# * The Dataset is collected from Website named, UCI Machine Learning Repository.
# * Link for dataset - https://archive.ics.uci.edu/ml/datasets/Algerian+Forest+Fires+Dataset++
# * This dataset includes 244 instances that regroup a data of 2 regions of Algeria,namely the Brjajia region located in the     northeast of Algeria and the Sidi Bel-abbes region located in the northwest of Algeria .
# 122 instances for each region .
# * The Period is from June 2012 to September 2012.The Dataset includes 11 attributes and 1 output attribute i.e. Temperature
# * The data consists of 14 column and 246 rows.

# %% [markdown]
# #### Importing Data and Required Packadges :

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
sns.set(rc={'figure.figsize':(10,8)})

# %% [markdown]
# #### Loading dataset :

# %%
df = pd.read_csv('Algerian_forest_fires_dataset_UPDATE.csv' , header = 1)

# %% [markdown]
# #### Sample Records :

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0   1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1   2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2   3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3   4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4   5     6  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes
# 0  not fire
# 1  not fire
# 2  not fire
# 3  not fire
# 4  not fire

# %% [markdown]
# #### Features Information :-
#
# __Period Covered__
#
# * Date : (DD/MM/YYYY) Day, month ('june' to 'september'), year (2012)
#
# __Weather__
#
# * temperature noon (temperature max) in Celsius degrees
# * RH : Relative Humidity in %
# * Ws :Wind speed in km/h
# * Rain: total day in mm
#
# __FWI Components__
#
# * Fine Fuel Moisture Code (FFMC) index from the FWI system
# * Duff Moisture Code (DMC) index from the FWI system
# * Drought Code (DC) index from the FWI system
# * Initial Spread Index (ISI) index from the FWI system
# * Buildup Index (BUI) index from the FWI system
# * Fire Weather Index (FWI) Index
# * Classes: two classes, namely Fire and not Fire

# %%
df.tail()
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 242  26     9  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 243  27     9  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 244  28     9  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 245  29     9  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 246  30     9  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes
# 242  6.5       fire
# 243    0   not fire
# 244  0.2   not fire
# 245  0.7   not fire
# 246  0.5  not fire

# %% [markdown]
# ### 3. Data Cleaning :
#
# __Removing Unneccesary row from the dataset:__

# %%
# We need to remove the 123rd and 124th index that represents the heaqder for other region

# %%
df.loc[120:125,:]
# Out:
#                                day  month  year  Temperature   RH   Ws  Rain   \
# 120                             29      9  2012           26   80   16    1.8
# 121                             30      9  2012           25   78   14    1.4
# 122                            NaN    NaN   NaN          NaN  NaN  NaN    NaN
# 123  Sidi-Bel Abbes Region Dataset    NaN   NaN          NaN  NaN  NaN    NaN
# 124                            day  month  year  Temperature   RH   Ws  Rain
# 125                              1      6  2012           32   71   12    0.7
#
#      FFMC  DMC   DC  ISI  BUI  FWI    Classes
# 120  47.4  2.9  7.7  0.3    3  0.1  not fire
# 121    45  1.9  7.5  0.2  2.4  0.1  not fire
# 122   NaN  NaN  NaN  NaN  NaN  NaN          NaN
# 123   NaN  NaN  NaN  NaN  NaN  NaN          NaN
# 124  FFMC  DMC   DC  ISI  BUI  FWI    Classes
# 125  57.1  2.5  8.2  0.6  2.8  0.2  not fire

# %%
# Dropping row no 122 specifying region name & 123 respecifying the header
df.drop(index=[122,123,124], inplace=True)

# %% [markdown]
# __Resetting the index and dropping the index column__

# %%
df.reset_index(inplace=True)
df.drop('index', axis=1, inplace=True)

# %% [markdown]
# __Creating a new column called 'Region' representing area as Bejaia and Sidi Bel-abbes__

# %%
df.loc[:122,"Region"]='Bejaia'
df.loc[122:,"Region"]='Sidi Bel-abbess'

# %%
# Checking Column headers :
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes  ', 'Region'],
#       dtype='object')

# %%
df.loc[120:125,:]
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 120  29     9  2012          26  80  16   1.8  47.4  2.9   7.7  0.3    3  0.1
# 121  30     9  2012          25  78  14   1.4    45  1.9   7.5  0.2  2.4  0.1
# 122   1     6  2012          32  71  12   0.7  57.1  2.5   8.2  0.6  2.8  0.2
# 123   2     6  2012          30  73  13     4  55.7  2.7   7.8  0.6  2.9  0.2
# 124   3     6  2012          29  80  14     2  48.7  2.2   7.6  0.3  2.6  0.1
# 125   4     6  2012          30  64  14     0  79.4  5.2  15.4  2.2  5.6    1
#
#        Classes             Region
# 120  not fire              Bejaia
# 121  not fire              Bejaia
# 122  not fire     Sidi Bel-abbess
# 123  not fire     Sidi Bel-abbess
# 124  not fire     Sidi Bel-abbess
# 125  not fire     Sidi Bel-abbess

# %% [markdown]
# #### Removing unnecessary spaces from different features and rows

# %%
# Removing Unneccesary space in column headers :
df.columns=df.columns.str.strip()
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %%
# Stripping the Classes Features data

df.Classes = df.Classes.str.strip()
df['Classes'].unique()
# Out:
# array(['not fire', 'fire', nan], dtype=object)

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  \
# 0   1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1   2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2   3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3   4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4   5     6  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#     Classes  Region
# 0  not fire  Bejaia
# 1  not fire  Bejaia
# 2  not fire  Bejaia
# 3  not fire  Bejaia
# 4  not fire  Bejaia

# %% [markdown]
# #### Changing Datatype of necessary  columns

# %%
df.dtypes
# Out:
# day            object
# month          object
# year           object
# Temperature    object
# RH             object
# Ws             object
# Rain           object
# FFMC           object
# DMC            object
# DC             object
# ISI            object
# BUI            object
# FWI            object
# Classes        object
# Region         object
# dtype: object

# %%
#changing datatypes

df[['day', 'month', 'year', 'Temperature', 'RH', 'Ws']]=df[['day', 'month', 'year', 'Temperature', 'RH', 'Ws']].astype(int)

# %%
df[['Rain', 'FFMC','DMC', 'DC', 'ISI', 'BUI', 'FWI']]=df[['Rain', 'FFMC','DMC', 'DC', 'ISI', 'BUI', 'FWI']].astype(float)

# %%
df['Region'] = df['Region'].astype(object)

# %%
df.dtypes
# Out:
# day              int32
# month            int32
# year             int32
# Temperature      int32
# RH               int32
# Ws               int32
# Rain           float64
# FFMC           float64
# DMC            float64
# DC             float64
# ISI            float64
# BUI            float64
# FWI            float64
# Classes         object
# Region          object
# dtype: object

# %%
# Adding New Feature 'Date' by Replacing Unnecessary feature like 'day','month','year'.

df['date'] = pd.to_datetime(df[['year','month','day']])
df.drop(['day', 'month', 'year'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI   Classes  \
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5  not fire
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4  not fire
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1  not fire
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0  not fire
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5  not fire
#
#    Region       date
# 0  Bejaia 2012-06-01
# 1  Bejaia 2012-06-02
# 2  Bejaia 2012-06-03
# 3  Bejaia 2012-06-04
# 4  Bejaia 2012-06-05

# %%
df.dtypes
# Out:
# Temperature             int32
# RH                      int32
# Ws                      int32
# Rain                  float64
# FFMC                  float64
# DMC                   float64
# DC                    float64
# ISI                   float64
# BUI                   float64
# FWI                   float64
# Classes                object
# Region                 object
# date           datetime64[ns]
# dtype: object

# %% [markdown]
# ## 4. EDA
#
# #### Shape of the dataframe

# %%
df.shape
# Out:
# (244, 13)

# %% [markdown]
# __Observation__:
# There rae 13 columns and 244 rows in the dataframe
#
#
# #### Columns

# %%
df.columns
# Out:
# Index(['Temperature', 'RH', 'Ws', 'Rain', 'FFMC', 'DMC', 'DC', 'ISI', 'BUI',
#        'FWI', 'Classes', 'Region', 'date'],
#       dtype='object')

# %% [markdown]
# #### Basic info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  244 non-null    int32
#  1   RH           244 non-null    int32
#  2   Ws           244 non-null    int32
#  3   Rain         244 non-null    float64
#  4   FFMC         244 non-null    float64
#  5   DMC          244 non-null    float64
#  6   DC           244 non-null    float64
#  7   ISI          244 non-null    float64
#  8   BUI          244 non-null    float64
#  9   FWI          244 non-null    float64
#  10  Classes      243 non-null    object
#  11  Region       244 non-null    object
#  12  date         244 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(7), int32(3), object(2)
# memory usage: 22.0+ KB

# %% [markdown]
# __observation:__
# The memory usage is 21.1 kb

# %% [markdown]
# #### Dataframe Description

# %%
df.describe()
# Out:
#        Temperature          RH          Ws        Rain        FFMC  \
# count   244.000000  244.000000  244.000000  244.000000  244.000000
# mean     32.172131   61.938525   15.504098    0.760656   77.887705
# std       3.633843   14.884200    2.810178    1.999406   14.337571
# min      22.000000   21.000000    6.000000    0.000000   28.600000
# 25%      30.000000   52.000000   14.000000    0.000000   72.075000
# 50%      32.000000   63.000000   15.000000    0.000000   83.500000
# 75%      35.000000   73.250000   17.000000    0.500000   88.300000
# max      42.000000   90.000000   29.000000   16.800000   96.000000
#
#               DMC          DC         ISI         BUI         FWI
# count  244.000000  244.000000  244.000000  244.000000  244.000000
# mean    14.673361   49.288484    4.774180   16.664754    7.036066
# std     12.368039   47.619393    4.175318   14.204824    7.425250
# min      0.700000    6.900000    0.000000    1.100000    0.000000
# 25%      5.800000   13.275000    1.400000    6.000000    0.700000
# 50%     11.300000   33.100000    3.500000   12.250000    4.450000
# 75%     20.750000   68.150000    7.300000   22.525000   11.375000
# max     65.900000  220.400000   19.000000   68.000000   31.100000

# %% [markdown]
# ### Misssing Data

# %%
df.isnull().sum()
# Out:
# Temperature    0
# RH             0
# Ws             0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        1
# Region         0
# date           0
# dtype: int64

# %% [markdown]
# __observation__ :
#     There is only 1 null value in 'Classes' column.
#
# #### Handling Missing Data
#
# * First we will handle this categorical feature by repplacing 0 for 'not fire' and 1 for 'fire'.
# * Then we will find median of the 'Classes' columnn and replcae null value with it

# %%
df['Classes'].unique()
# Out:
# array(['not fire', 'fire', nan], dtype=object)

# %%
df['Classes'] = df['Classes'].map({'not fire':0 , 'fire':1})

# %%
df.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  Classes  Region  \
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5      0.0  Bejaia
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4      0.0  Bejaia
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1      0.0  Bejaia
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0      0.0  Bejaia
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5      0.0  Bejaia
#
#         date
# 0 2012-06-01
# 1 2012-06-02
# 2 2012-06-03
# 3 2012-06-04
# 4 2012-06-05

# %%
# Focus on Replacing Null Value
# The best Way of Replacing Null Value by using mode

df['Classes'].median()
# Out:
# 1.0

# %%
df['Classes']=df['Classes'].fillna(df['Classes'].median())
df['Classes'] = df['Classes'].astype(object)

# %%
df.isnull().sum()
# Out:
# Temperature    0
# RH             0
# Ws             0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        0
# Region         0
# date           0
# dtype: int64

# %% [markdown]
# __Observation:__
# There is now no null value left in the dataframe
#
# __Column wise memory usage__:

# %%
df.memory_usage()
# Out:
# Index           128
# Temperature     976
# RH              976
# Ws              976
# Rain           1952
# FFMC           1952
# DMC            1952
# DC             1952
# ISI            1952
# BUI            1952
# FWI            1952
# Classes        1952
# Region         1952
# date           1952
# dtype: int64

# %% [markdown]
# ## Numerical and Categorical Columns
#
# #### Numerical Columns

# %%
num_feat = [fea for fea in df.columns if df[fea].dtypes != 'O']
  
print('We have {} numerical features : {}'.format(len(num_feat), num_feat))
# Out:
# We have 11 numerical features : ['Temperature', 'RH', 'Ws', 'Rain', 'FFMC', 'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'date']

# %% [markdown]
# #### Categorical Columns

# %%
cat_feat = [fea for fea in df.columns if df[fea].dtypes == 'O']
  
print('We have {} categorical features : {}'.format(len(cat_feat), cat_feat))
# Out:
# We have 2 categorical features : ['Classes', 'Region']

# %% [markdown]
# ## Univariate Analysis

# %%
df.var()
# Out:
# Temperature      13.204817
# RH              221.539415
# Ws                7.897102
# Rain              3.997623
# FFMC            205.565939
# DMC             152.968382
# DC             2267.606583
# ISI              17.433281
# BUI             201.777024
# FWI              55.134332
# Classes           0.246711
# dtype: float64

# %% [markdown]
# #### Numerical Features

# %%
plt.figure(figsize=(15, 15))
plt.suptitle('Univariate Analysis of Numerical Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.)

for i in range(0, len(num_feat)):
    plt.subplot(5, 3, i+1)
    sns.kdeplot(x=df[num_feat[i]],shade=True, color='b')
    plt.xlabel(num_feat[i])
    plt.tight_layout()

# %% [markdown]
# #### Scatter plot for trend

# %%
plt.figure(figsize=(15, 20))
plt.suptitle('scatter plot for numerical feature', fontsize=20, fontweight='bold', alpha=1, y=1)

for i in range(0, len(num_feat)):
    plt.subplot(5, 3, i+1)
    sns.scatterplot(y=num_feat[i], x=df.index, data=df , color = 'b')
    plt.tight_layout()

# %% [markdown]
# #### Categorical Features

# %%
plt.figure(figsize=(15, 15))
plt.suptitle('Univariate Analysis of Categorical Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.)

for i in range(0, len(cat_feat)):
    plt.subplot(5, 3, i+1)
    sns.countplot(x=df[cat_feat[i]])
    plt.tight_layout()

# %% [markdown]
# ## Bivariate Analysis
#
# #### Correlation between different variables:

# %%
df.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.654443 -0.278132 -0.326786  0.677491  0.483105
# RH             -0.654443  1.000000  0.236084  0.222968 -0.645658 -0.405133
# Ws             -0.278132  0.236084  1.000000  0.170169 -0.163255 -0.001246
# Rain           -0.326786  0.222968  0.170169  1.000000 -0.544045 -0.288548
# FFMC            0.677491 -0.645658 -0.163255 -0.544045  1.000000  0.602391
# DMC             0.483105 -0.405133 -0.001246 -0.288548  0.602391  1.000000
# DC              0.370511 -0.220344  0.076253 -0.296808  0.503919  0.875362
# ISI             0.607551 -0.690637  0.015248 -0.347105  0.739730  0.674499
# BUI             0.455504 -0.348587  0.029756 -0.299171  0.589652  0.982073
# FWI             0.564720 -0.577730  0.032396 -0.324394  0.690358  0.875813
#
#                    DC       ISI       BUI       FWI
# Temperature  0.370511  0.607551  0.455504  0.564720
# RH          -0.220344 -0.690637 -0.348587 -0.577730
# Ws           0.076253  0.015248  0.029756  0.032396
# Rain        -0.296808 -0.347105 -0.299171 -0.324394
# FFMC         0.503919  0.739730  0.589652  0.690358
# DMC          0.875362  0.674499  0.982073  0.875813
# DC           1.000000  0.498926  0.941906  0.738647
# ISI          0.498926  1.000000  0.635891  0.916511
# BUI          0.941906  0.635891  1.000000  0.857587
# FWI          0.738647  0.916511  0.857587  1.000000

# %% [markdown]
# #### Pairplot

# %%
sns.pairplot(data = df)

# %% [markdown]
# #### Heatmap for correlation

# %%
plt.figure(figsize = (15,15))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# __Observation__:
#
# * RH is negatively corelated with Temperature, FFMC, ISI and FWI
# * Rain is negatively correlated with Temperature and FFMC,DMC, ISI and BUI
# * FFMC is highly positively correlated with ISI , BUI , DC , DMC and FFMC

# %% [markdown]
# #### Strip plot for Numerical fearures and classes

# %%
plt.figure(figsize=(15, 20))
plt.suptitle('Strip Plot ( 0 for Not Fire and 1 for Fire)', fontsize=20, fontweight='bold', alpha = 0.9, y=1)
pal = ['blue' , 'green']


for i in range(0, len(num_feat)):
    plt.subplot(5, 3, i+1)
    sns.stripplot(y=num_feat[i], x='Classes', data=df , palette = pal )
    plt.tight_layout()

# %% [markdown]
# __Observation:__
#
# * Regions with Higher Temperature , FFMC , ISI , FWI , BUI  have more chances of Fire
# * Temp is directly proportional to Fire and high FFMC has strong Impact on fire

# %% [markdown]
# ### Boxplot for Outliers:

# %%
plt.figure(figsize=(20, 15))

sns.boxplot(data = df , orient = "v")
# Out:
# <AxesSubplot:>

# %% [markdown]
# __Observation:__
# * Features like Rain , FFMC, DMC , DC , BUI have many Outliers

# %% [markdown]
# ## Graphical Analysis
#
# ### Region where Fire breaks out most times:

# %%
plt.figure(figsize=(10,10)) 
sns.barplot( x = 'Region' , y = 'Classes' , data = df  )
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Classes'>

# %% [markdown]
# __Observation:__
# The Sidi Bel-abbess region has more cases of Fire breaking Out than Bejaia region

# %% [markdown]
# ### Temperature condition in most of areas

# %%
plt.subplots(figsize=(17,10))
sns.histplot("Distribution of Temperature",x=df.Temperature,color='g',kde=True)
plt.title("Distribution of Temperature",weight='bold',fontsize=20,pad=20)
plt.xlabel("Temperature",weight='bold',fontsize=15)
plt.ylabel("Count",weight='bold',fontsize=15)
plt.show()

# %% [markdown]
# __Observation:__
# Temperature is mostly between 30-35 degree celcius

# %% [markdown]
# ### What is the average temperature of different regions ?

# %%
plt.subplots(figsize=(17,10))
sns.barplot(y =df['Temperature'], x = df['Region'] , data = df )
plt.title("Avg Temperature of Both Regions",weight='bold',fontsize=20,pad=20)
# Out:
# Text(0.5, 1.0, 'Avg Temperature of Both Regions')

# %% [markdown]
# __Observation:__
# Sidi Bel-abbess region has comaprarively higher avg temperature than Bejaia region

# %%
df['Temperature'].groupby(df['Region']).mean()
# Out:
# Region
# Bejaia             31.180328
# Sidi Bel-abbess    33.163934
# Name: Temperature, dtype: float64

# %% [markdown]
# #### Percentage of fire

# %%
percentage=df.Classes.value_counts(normalize=True)*100
classes_labels=['Fire','Not Fire']
plt.figure(figsize=(15,10))
plt.pie(percentage,labels=classes_labels,autopct="%1.1f%%")
plt.title("Pie Chart of Classes",fontsize=15)
plt.show()

# %% [markdown]
# __Observation:__
# On 56.6% of days recorded , Fire broke out

# %% [markdown]
# ### Relation between Rain and region

# %%
sns.barplot(x="Region",y="Rain",data=df)
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Rain'>

# %%
plt.figure(figsize=(10,10))
pal = ['green' ,'blue']
df['Rain'].groupby( df['Region']).mean().plot(kind = 'pie' ,autopct='%.0f%%' )
plt.title('Percentage Of Rain in Both regions' , fontweight = 'bold' , fontsize = 20 )
plt.show()

# %% [markdown]
# __Observation:__
# The bejaia region had comparatively more Rain than Sidi bel-abbess region.
#
# #### Regression plot for effect of TEmperature on different factorrs

# %%
sns.regplot(x='FFMC',y='Temperature',data=df )
# Out:
# <AxesSubplot:xlabel='FFMC', ylabel='Temperature'>

# %%
print(sns.regplot(x='FWI',y='Temperature',data=df , color = 'g'))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
sns.regplot(x='DMC',y='Temperature',data=df , color = 'purple')
# Out:
# <AxesSubplot:xlabel='DMC', ylabel='Temperature'>

# %%
sns.regplot(x='Rain',y='Temperature',data=df)
# Out:
# <AxesSubplot:xlabel='Rain', ylabel='Temperature'>

# %% [markdown]
# __Observation:__
# Temperature has  :
# * positive linear relation with FFMC i.e. more the number of cured fine fuels and moisture more is the temperature.
# * positive linear relation with FWI i.e. More the temperature , more is the potential of Forest Fire.
# * positive linear relation with DMC i.e. More the organic content as moisture , more is the potential of Forest Fire.
# * negative linear relation with Rain

# %%
# Regex plot for all FWI components : 

plt.figure(figsize = (15,10))
print(sns.regplot(x='FFMC',y='Temperature',data=df ))
print(sns.regplot(x='DMC',y='Temperature',data=df, color = 'green'))
print(sns.regplot(x='DC',y='Temperature',data=df, color= 'red'))
print(sns.regplot(x='ISI',y='Temperature',data=df, color = 'purple'))
print(sns.regplot(x='BUI',y='Temperature',data=df, color = 'black'))
print(sns.regplot(x='FWI',y='Temperature',data=df , color = 'grey'))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# __Observation:__
# Out of all FWI components FFMC and ISI have more Impact on the temperature

# %% [markdown]
# ### Which Region had the higher RH ?

# %%
plt.figure(figsize = (10,10))
palette = ['green' ,'red']
ax = sns.barplot(x = "Region" , y = "RH" , hue = 'Classes' , data = df , palette =palette , errwidth = 0 )
for i in ax.containers:
    ax.bar_label(i,)

# %% [markdown]
# __Observation:__
# * Bejaia region had more RH value in cae of both Fire and Not Fire
#
#
#
# __Final Report__:
#
# * There are 244 rows and 13 colummn in the dataset, we had to assign and edit some columns name .
# * The target column is Classes which tells us whether there was fire or not on a given day in different regions.
# * Features like Rain , FFMC, DMC , DC , BUI have many Outliers.
# * Temperature is directly proportional to fire
# * Bejaia region was more affected by fire , even if there was more percentage of Rain in that area .
# * FFMC and ISI are the main components effecting the growth of the temperature.
# * Bejaia region had more average rainfall and also higher RH

# %%
# Saving The Structured File : 
df.to_csv('Algerian_Forest_Fire_Cleaned.csv' , index = False )

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  244 non-null    int32
#  1   RH           244 non-null    int32
#  2   Ws           244 non-null    int32
#  3   Rain         244 non-null    float64
#  4   FFMC         244 non-null    float64
#  5   DMC          244 non-null    float64
#  6   DC           244 non-null    float64
#  7   ISI          244 non-null    float64
#  8   BUI          244 non-null    float64
#  9   FWI          244 non-null    float64
#  10  Classes      244 non-null    object
#  11  Region       244 non-null    object
#  12  date         244 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(7), int32(3), object(2)
# memory usage: 22.0+ KB

# %%
df['Classes'] = df['Classes'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  244 non-null    int32
#  1   RH           244 non-null    int32
#  2   Ws           244 non-null    int32
#  3   Rain         244 non-null    float64
#  4   FFMC         244 non-null    float64
#  5   DMC          244 non-null    float64
#  6   DC           244 non-null    float64
#  7   ISI          244 non-null    float64
#  8   BUI          244 non-null    float64
#  9   FWI          244 non-null    float64
#  10  Classes      244 non-null    float64
#  11  Region       244 non-null    object
#  12  date         244 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(8), int32(3), object(1)
# memory usage: 22.0+ KB

# %% [markdown]
# ## Independent and Dependent Features Of the model

# %%
df.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  Classes  Region  \
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5      0.0  Bejaia
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4      0.0  Bejaia
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1      0.0  Bejaia
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0      0.0  Bejaia
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5      0.0  Bejaia
#
#         date
# 0 2012-06-01
# 1 2012-06-02
# 2 2012-06-03
# 3 2012-06-04
# 4 2012-06-05

# %% [markdown]
# We are goint to predict the __Temperature__ so it will be the __Output Feature__ and rest all numerical features will be __Input Features__.
#
#   Firstly we will drop all the non essential columns like date and region .
#
#
# ## Cleaning Data for modelling
#
# ### Dropping unneccesary features

# %%
df.drop(labels = ["Region"] , inplace = True , axis = 1)

# %%
df.drop(labels = ["date"] , inplace = True , axis = 1)

# %%
df.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  Classes
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5      0.0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4      0.0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1      0.0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0      0.0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5      0.0

# %%
# Input Features 
x = df.iloc[:, 1:]

#Output Feature
y = df.iloc[: , 0]

# %%
x
# Out:
#      RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  FWI  Classes
# 0    57  18   0.0  65.7   3.4   7.6  1.3   3.4  0.5      0.0
# 1    61  13   1.3  64.4   4.1   7.6  1.0   3.9  0.4      0.0
# 2    82  22  13.1  47.1   2.5   7.1  0.3   2.7  0.1      0.0
# 3    89  13   2.5  28.6   1.3   6.9  0.0   1.7  0.0      0.0
# 4    77  16   0.0  64.8   3.0  14.2  1.2   3.9  0.5      0.0
# ..   ..  ..   ...   ...   ...   ...  ...   ...  ...      ...
# 239  65  14   0.0  85.4  16.0  44.5  4.5  16.9  6.5      1.0
# 240  87  15   4.4  41.1   6.5   8.0  0.1   6.2  0.0      0.0
# 241  87  29   0.5  45.9   3.5   7.9  0.4   3.4  0.2      0.0
# 242  54  18   0.1  79.7   4.3  15.2  1.7   5.1  0.7      0.0
# 243  64  15   0.2  67.3   3.8  16.5  1.2   4.8  0.5      0.0
#
# [244 rows x 10 columns]

# %%
y
# Out:
# 0      29
# 1      29
# 2      26
# 3      25
# 4      27
#        ..
# 239    30
# 240    28
# 241    27
# 242    24
# 243    24
# Name: Temperature, Length: 244, dtype: int32

# %% [markdown]
# ## Creating Train and Test Data:

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=0)

# %%
x_train
# Out:
#      RH  Ws  Rain  FFMC   DMC     DC   ISI   BUI   FWI  Classes
# 171  50  16   0.0  89.9  32.7   71.0   9.5  32.6  17.3      1.0
# 89   48  18   0.0  90.1  54.2  220.4  12.5  67.4  30.2      1.0
# 157  42  15   0.3  84.7  15.5   45.1   4.3  16.7   6.3      1.0
# 219  71  14   6.5  64.5   3.3    9.1   1.0   3.5   0.4      0.0
# 234  34  17   0.0  92.2  23.6   97.3  13.8  29.4  21.6      1.0
# ..   ..  ..   ...   ...   ...    ...   ...   ...   ...      ...
# 67   69  16   0.0  86.5  15.5   48.6   5.5  17.2   8.0      1.0
# 192  39  15   0.2  89.3  15.8   35.4   8.2  15.8  10.7      1.0
# 117  54  11   0.0  82.0   6.0   16.3   2.5   6.2   1.7      0.0
# 47   68  14   0.0  85.4  12.1   43.1   4.6  14.2   6.0      1.0
# 172  29  18   0.0  93.9  39.6   80.6  18.5  39.5  30.0      1.0
#
# [183 rows x 10 columns]

# %%
y_train
# Out:
# 171    36
# 89     35
# 157    35
# 219    34
# 234    35
#        ..
# 67     32
# 192    39
# 117    31
# 47     31
# 172    36
# Name: Temperature, Length: 183, dtype: int32

# %%
x_test
# Out:
#      RH  Ws  Rain  FFMC   DMC    DC   ISI   BUI   FWI  Classes
# 64   69  13   0.0  85.0   8.2  19.8   4.0   8.2   3.9      1.0
# 63   63  14   0.3  76.6   5.7  10.0   1.7   5.5   0.8      0.0
# 55   53  19   0.0  89.2  17.1  98.6  10.0  23.9  15.3      1.0
# 111  84  18   0.0  83.8  13.5  49.3   4.5  16.0   6.3      1.0
# 225  72  14   0.0  84.2   8.3  25.2   3.8   9.1   3.9      1.0
# ..   ..  ..   ...   ...   ...   ...   ...   ...   ...      ...
# 116  81  21   5.8  48.6   3.0   7.7   0.4   3.0   0.1      0.0
# 33   78  17   0.0  80.1   4.6  18.5   2.7   5.7   1.7      0.0
# 122  71  12   0.7  57.1   2.5   8.2   0.6   2.8   0.2      0.0
# 161  51  16   3.8  77.5   8.0   9.5   2.0   7.7   1.3      0.0
# 96   75  16   0.0  80.8   3.4  24.0   2.8   5.1   1.7      1.0
#
# [61 rows x 10 columns]

# %%
y_test
# Out:
# 64     34
# 63     35
# 55     36
# 111    28
# 225    31
#        ..
# 116    26
# 33     33
# 122    32
# 161    34
# 96     29
# Name: Temperature, Length: 61, dtype: int32

# %%
print(x_train.shape , y_train.shape , x_test.shape , y_test.shape)
# Out:
# (183, 10) (183,) (61, 10) (61,)

# %% [markdown]
# ###  Checking multicolleniarity and remove highly correlated features

# %%
#Using Pearson Correlation
plt.figure(figsize=(12,10))
cor = x_train.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.CMRmap_r)
plt.show()

# %%
def correlation(dataset, threshold):
    col_corr = set()
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold: 
                colname = corr_matrix.columns[i]
                col_corr.add(colname)
    return col_corr

# %%
corr_features = correlation(x_train, 0.75)

# %%
# features which has correlation more than 0.75
corr_features
# Out:
# {'BUI', 'Classes', 'DC', 'FWI'}

# %%
# drop features which has correlation more than 0.75
x_train.drop(corr_features,axis=1, inplace=True)
x_test.drop(corr_features,axis=1, inplace=True)
x_train.shape, x_test.shape
# Out:
# ((183, 6), (61, 6))

# %% [markdown]
# ## Feature Scaling

# %%
## standardize the dataset
## With standardization we reach the global minima faster

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler
# Out:
# StandardScaler()

# %% [markdown]
# #### Fitting data

# %%
def scaler_standard(x_train, x_test):
    x_train_scaled = scaler.fit_transform(x_train)
    x_test_scaled = scaler.transform(x_test) 
    return x_train_scaled, x_test_scaled

# %%
x_train_scaled, x_test_scaled = scaler_standard(x_train, x_test)

# %%
x_test_scaled
# Out:
# array([[ 0.55774201, -0.90393443, -0.36651526,  0.47217761, -0.57213399,
#         -0.23447856],
#        [ 0.15351711, -0.55122654, -0.22560708, -0.11946848, -0.77121468,
#         -0.76139808],
#        [-0.52019107,  1.21231291, -0.36651526,  0.76800065,  0.13659329,
#          1.1400941 ],
#        [ 1.56830427,  0.85960502, -0.36651526,  0.38765674, -0.15008291,
#         -0.11993084],
#        [ 0.75985447, -0.55122654, -0.36651526,  0.41583036, -0.56417076,
#         -0.28029765],
#        [ 1.02933773,  0.50689713,  3.01528102, -2.27475066, -1.12159671,
#         -1.10504124],
#        [ 0.01877547,  0.85960502, -0.22560708,  0.13409413, -0.29342101,
#         -0.50939309],
#        [-0.31807861,  0.15418924, -0.36651526,  0.74687044,  0.67012955,
#          0.7277223 ],
#        [-0.45282025, -0.55122654,  1.08953592, -0.54911623, -0.34916361,
#         -0.85303626],
#        [-0.11596616,  0.15418924, -0.36651526,  0.69052319,  0.32771076,
#          0.54444595],
#        [ 0.15351711, -0.19851865, -0.36651526,  0.61304573,  0.28789462,
#          0.20080278],
#        [ 0.28825874, -0.55122654, -0.36651526, -0.01381739, -0.97029538,
#         -0.71557899],
#        [-1.66549496, -0.90393443, -0.08469891,  0.55669848,  0.20029911,
#         -0.05120221],
#        [-1.32864087, -1.9620581 , -0.31954587,  0.96521602,  0.57457082,
#          1.02554638],
#        [ 0.82722528, -0.55122654, -0.36651526,  0.06366007, -0.70750886,
#         -0.6697599 ],
#        [ 1.298821  ,  1.21231291, -0.17863769, -1.23937   , -0.81103082,
#         -0.89885534],
#        [ 0.4903712 ,  0.15418924, -0.36651526,  0.49330783, -0.42879589,
#         -0.02829266],
#        [-0.2507078 , -0.55122654, -0.36651526,  0.77504406, -0.22971519,
#          0.63608412],
#        [ 0.22088793, -0.19851865, -0.27257648, -0.77450522, -0.92251601,
#         -0.8759458 ],
#        [ 0.15351711, -0.90393443,  0.99559713, -0.60546348, -0.65176626,
#         -0.8759458 ],
#        [-0.31807861, -0.55122654, -0.17863769,  0.06366007,  1.72127563,
#         -0.6697599 ],
#        [ 1.70304591,  1.91772869,  1.79407681, -2.63396436, -1.12159671,
#         -1.12795079],
#        [ 0.55774201,  0.50689713,  1.8410462 , -1.13371892, -0.91455278,
#         -0.89885534],
#        [ 1.83778754, -0.90393443, -0.27257648, -1.78875566, -0.59602367,
#         -1.05922215],
#        [-2.47394477, -2.31476599, -0.36651526,  1.24695225,  1.18773936,
#          2.44593812],
#        [ 0.69248365, -0.19851865, -0.36651526,  0.54261167,  1.7133124 ,
#          0.01752643],
#        [ 0.08614629, -0.19851865, -0.36651526,  0.35243971, -0.76325145,
#         -0.28029765],
#        [ 0.22088793, -0.55122654, -0.36651526,  0.07774688, -0.81103082,
#         -0.64685036],
#        [ 0.42300038, -0.55122654, -0.36651526,  0.30313587, -0.76325145,
#         -0.44066446],
#        [ 0.08614629,  0.85960502, -0.31954587,  0.218615  , -0.57213399,
#         -0.39484537],
#        [ 0.35562956, -0.55122654, -0.36651526,  0.61304573,  0.50290177,
#          0.15498369],
#        [ 1.298821  , -0.55122654,  0.57287259, -2.0845787 , -1.04992766,
#         -1.0821317 ],
#        [ 1.56830427,  1.91772869,  0.19711745, -1.99301443, -0.6915824 ,
#         -1.03631261],
#        [ 1.36619182,  0.50689713, -0.36651526,  0.44400399,  0.4551224 ,
#         -0.07411175],
#        [ 1.02933773,  1.91772869, -0.36651526, -0.40120471, -0.66769272,
#         -0.99049352],
#        [-1.19389924, -0.90393443, -0.1316683 ,  0.47217761, -0.18989905,
#         -0.21156902],
#        [ 0.4903712 ,  1.21231291, -0.36651526,  0.51443804, -0.22971519,
#          0.22371233],
#        [ 1.97252918, -0.19851865, -0.36651526, -0.80972225, -0.65176626,
#         -0.8759458 ],
#        [-0.78967434, -0.19851865, -0.36651526,  0.76800065,  0.74976183,
#          0.70481276],
#        [ 0.8945961 , -0.19851865,  0.15014806, -1.32389087, -0.85084696,
#         -0.96758398],
#        [ 1.298821  , -0.19851865, -0.36651526,  0.3383529 , -0.59602367,
#         -0.34902628],
#        [ 0.35562956, -1.60935021, -0.36651526,  0.52148145, -0.56417076,
#         -0.23447856],
#        [-1.86760741, -0.90393443, -0.31954587,  0.86660834,  0.82939411,
#          0.91099865],
#        [-0.18333698,  0.85960502, -0.36651526,  0.68347978, -0.14211968,
#          0.68190321],
#        [-0.45282025, -0.55122654, -0.36651526,  0.89478196,  4.02264847,
#          1.1400941 ],
#        [-0.38544943,  0.15418924, -0.31954587,  0.11296391, -0.86677342,
#         -0.57812172],
#        [-0.58756188, -0.55122654, -0.36651526,  0.66234957, -0.71547209,
#          0.26953141],
#        [ 1.90515836, -0.90393443, -0.03772951, -2.97204783, -1.08974379,
#         -1.15086033],
#        [ 0.15351711, -0.90393443, -0.36651526,  0.74687044,  0.50290177,
#          0.47571731],
#        [ 0.82722528, -0.19851865, -0.36651526,  0.5848721 , -0.2615681 ,
#          0.13207415],
#        [-0.52019107,  0.15418924, -0.36651526,  0.78913087,  1.76905499,
#          1.23173227],
#        [ 0.22088793, -2.31476599,  0.19711745, -0.31668384, -0.29342101,
#         -0.89885534],
#        [ 1.43356264, -0.19851865, -0.17863769, -2.35222812, -1.15344962,
#         -1.10504124],
#        [-1.0591576 ,  0.85960502, -0.36651526,  0.85956493,  0.26400494,
#          1.43791817],
#        [ 1.77041673,  0.85960502, -0.36651526,  0.12000732, -0.28545778,
#         -0.50939309],
#        [ 0.8945961 ,  1.21231291, -0.31954587, -0.17581573, -0.93844247,
#         -0.6697599 ],
#        [ 1.36619182,  1.91772869,  2.35770952, -2.09162211, -0.98622183,
#         -1.05922215],
#        [ 1.16407937,  0.50689713, -0.36651526,  0.12705072, -0.85881019,
#         -0.53230264],
#        [ 0.69248365, -1.25664232, -0.03772951, -1.49293261, -1.02603797,
#         -1.01340307],
#        [-0.6549327 ,  0.15418924,  1.41832167, -0.05607783, -0.58806044,
#         -0.69266945],
#        [ 0.96196692,  0.15418924, -0.36651526,  0.17635457, -0.95436892,
#         -0.50939309]])

# %%
x_train_scaled
# Out:
# array([[-0.72230352,  0.15418924, -0.36651526,  0.81730449,  1.37885683,
#          1.02554638],
#        [-0.85704515,  0.85960502, -0.36651526,  0.83139131,  3.09095081,
#          1.7128327 ],
#        [-1.26127006, -0.19851865, -0.22560708,  0.45104739,  0.00918165,
#         -0.16574993],
#        ...,
#        [-0.45282025, -1.60935021, -0.36651526,  0.26087544, -0.747325  ,
#         -0.57812172],
#        [ 0.4903712 , -0.55122654, -0.36651526,  0.50035123, -0.2615681 ,
#         -0.09702129],
#        [-2.13709068,  0.85960502, -0.36651526,  1.09904073,  1.92831955,
#          3.08740536]])

# %% [markdown]
# #### Box plo to understand scaling

# %%
plt.subplots(figsize=(15, 5))
plt.subplot(1, 2, 1)
sns.boxplot(data=x_train)
plt.title('x_train Before Scaling')
plt.subplot(1, 2, 2)
sns.boxplot(data=x_train_scaled)
plt.title('x_train After Scaling')
# Out:
# Text(0.5, 1.0, 'x_train After Scaling')

# %% [markdown]
# # Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, r2_score , mean_squared_error

# Fitting Data into model
lreg = LinearRegression()
lreg.fit(x_train_scaled, y_train)

# Prediction  
lreg_pred = lreg.predict(x_test_scaled)

# Performance Metrics
mae = mean_absolute_error(y_test, lreg_pred)
r2 = r2_score(y_test, lreg_pred)
adjusted_r2 = 1 - (1-r2)*(len(y_test)-1)/(len(y_test)-x_test_scaled.shape[1]-1)
mse = mean_absolute_error(y_test, lreg_pred)
rmse = np.sqrt(mean_squared_error(y_test,lreg_pred))

print("Linear Regression")
print("The regression Coefficient are : " , lreg.coef_)
print("The Intercept  is : " , lreg.intercept_)
print ("MAE value: {:.4f}".format(mae))
print ("MSE value: {:.4f}".format(mse))
print(" RMSE value : ".format(rmse))
print ("R2 Score value: {:.4f}".format(r2))
print ("Adjusted R2 Score value: {:.4f}".format(adjusted_r2))
# Out:
# Linear Regression
# The regression Coefficient are :  [-8.97146480e-01 -4.71865325e-01 -1.06513890e-03  1.28336229e+00
#   1.32845727e-01  4.83357230e-01]
# The Intercept  is :  32.26229508196721
# MAE value: 1.9728
# MSE value: 1.9728
#  RMSE value :
# R2 Score value: 0.6244
# Adjusted R2 Score value: 0.5827

# %% [markdown]
# ## Assumption for linear regression

# %%
# 1. linearity
plt.scatter(y_test,lreg_pred) 
plt.xlabel("Test Truth Data")
plt.ylabel("Test Predicted Data")
# Out:
# Text(0, 0.5, 'Test Predicted Data')

# %%
# 2. residuals
residuals=y_test- lreg_pred
residuals
# Out:
# 64     1.394523
# 63     3.238888
# 55     2.287834
# 111   -2.869666
# 225   -1.164319
#          ...
# 116   -0.801893
# 33     2.229181
# 122    2.308072
# 161    1.709298
# 96    -2.180228
# Name: Temperature, Length: 61, dtype: float64

# %%
sns.displot(residuals,kind="kde")

# %%
# 3. homoscedasticity
plt.scatter(lreg_pred,residuals)
plt.xlabel('predicted values')
plt.ylabel('Residuals')
sns.lineplot([-8,42],[0,0],color='blue')
# Out:
# <AxesSubplot:xlabel='predicted values', ylabel='Residuals'>

# %% [markdown]
# # Ridge Regression Model

# %%
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_absolute_error, r2_score , mean_squared_error

# Fitting Data into model
ridge = Ridge()
ridge.fit(x_train_scaled, y_train)

# Predicting Test Data
ridge_pred = ridge.predict(x_test_scaled)

# Performance Metrics
mae = mean_absolute_error(y_test, ridge_pred)
r2 = r2_score(y_test, ridge_pred)
adjusted_r2 = 1 - (1-r2)*(len(y_test)-1)/(len(y_test)-x_test_scaled.shape[1]-1)
mse = mean_absolute_error(y_test, ridge_pred)
rmse = np.sqrt(mean_squared_error(y_test,ridge_pred))

print("Ridge Regression")
print("The regression Coefficient are : " , ridge.coef_)
print("The Intercept  is : " , ridge.intercept_)
print ("MAE value: {:.4f}".format(mae))
print ("MSE value: {:.4f}".format(mse))
print(" RMSE value : ".format(rmse))
print ("R2 Score value: {:.4f}".format(r2))
print ("Adjusted R2 Score value: {:.4f}".format(adjusted_r2))
# Out:
# Ridge Regression
# The regression Coefficient are :  [-0.89634081 -0.47120205 -0.00683078  1.26813397  0.13724341  0.48755885]
# The Intercept  is :  32.26229508196721
# MAE value: 1.9727
# MSE value: 1.9727
#  RMSE value :
# R2 Score value: 0.6241
# Adjusted R2 Score value: 0.5824

# %% [markdown]
# #### Checking Assumptions for Ridge model:

# %%
## 1. linearity
plt.scatter(y_test,ridge_pred) 
plt.xlabel("Test Truth Data")
plt.ylabel("Test Predicted Data")
sns.set(rc={'figure.figsize':(10,8)})

# %%
#2.residuals
residuals=y_test- ridge_pred
residuals
# Out:
# 64     1.403252
# 63     3.242601
# 55     2.291640
# 111   -2.866545
# 225   -1.156687
#          ...
# 116   -0.813736
# 33     2.233742
# 122    2.294165
# 161    1.722543
# 96    -2.174195
# Name: Temperature, Length: 61, dtype: float64

# %%
sns.displot(residuals,kind="kde")

# %%
# 3. homoscedesacity
plt.scatter(ridge_pred,residuals)
plt.xlabel('predicted values')
plt.ylabel('Residuals')
sns.lineplot([-8,42],[0,0],color='blue')
# Out:
# <AxesSubplot:xlabel='predicted values', ylabel='Residuals'>

# %% [markdown]
# # Lasso Regression Model

# %%
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_absolute_error, r2_score , mean_squared_error


lasso = Lasso()

#Fitting Data into model 

lasso.fit(x_train_scaled, y_train)

# Predicting Test Data
lasso_pred = lasso.predict(x_test_scaled)

#Performance Metrics
mae = mean_absolute_error(y_test, lasso_pred)
r2 = r2_score(y_test, lasso_pred)
adjusted_r2 = 1 - (1-r2)*(len(y_test)-1)/(len(y_test)-x_test_scaled.shape[1]-1)
mse = mean_absolute_error(y_test, lasso_pred)
rmse = np.sqrt(mean_squared_error(y_test,lasso_pred))

print("Lasso Regression")
print("The regression Coefficient are : " , lasso.coef_)
print("The Intercept  is : " , lasso.intercept_)
print ("MAE value: {:.4f}".format(mae))
print ("MSE value: {:.4f}".format(mse))
print(" RMSE value : ".format(rmse))
print ("R2 Score value: {:.4f}".format(r2))
print ("Adjusted R2 Score value: {:.4f}".format(adjusted_r2))
# Out:
# Lasso Regression
# The regression Coefficient are :  [-0.54005064 -0.         -0.          1.01993888  0.          0.        ]
# The Intercept  is :  32.26229508196721
# MAE value: 2.4591
# MSE value: 2.4591
#  RMSE value :
# R2 Score value: 0.4270
# Adjusted R2 Score value: 0.3633

# %% [markdown]
# #### Checking Assumptions for Lasso model

# %%
# 1 .linearity 
plt.scatter(y_test,lasso_pred) 
plt.xlabel("Test Truth Data")
plt.ylabel("Test Predicted Data")
# Out:
# Text(0, 0.5, 'Test Predicted Data')

# %%
# 2. residuals
residuals=y_test- lasso_pred
residuals
# Out:
# 64     1.557322
# 63     2.942462
# 55     2.673462
# 111   -3.810718
# 225   -1.276057
#          ...
# 116   -3.391156
# 33     1.236783
# 122    1.634381
# 161    1.441204
# 96    -2.922655
# Name: Temperature, Length: 61, dtype: float64

# %%
sns.displot(residuals,kind="kde")

# %%
# 3. Homoscedasticity
plt.scatter(lasso_pred,residuals)
plt.xlabel('predicted values')
plt.ylabel('Residuals')
sns.lineplot([-8,42],[0,0],color='blue')
# Out:
# <AxesSubplot:xlabel='predicted values', ylabel='Residuals'>

# %% [markdown]
# ## ElasticNet Regression Model

# %%
from sklearn.linear_model import ElasticNet
from sklearn.metrics import mean_absolute_error, r2_score , mean_squared_error


elsc = ElasticNet()

# Fitting Data into Model
elsc.fit(x_train_scaled, y_train)

# Predicting Test data

elsc_pred = elsc.predict(x_test_scaled)

# Performance metrics

mae = mean_absolute_error(y_test, elsc_pred)
r2 = r2_score(y_test, elsc_pred)
adjusted_r2 = 1 - (1-r2)*(len(y_test)-1)/(len(y_test)-x_test_scaled.shape[1]-1)
mse = mean_absolute_error(y_test, elsc_pred)
rmse = np.sqrt(mean_squared_error(y_test,elsc_pred))

print("Elastic Net Regression")
print("The regression Coefficient are : " , elsc.coef_)
print("The Intercept  is : " , elsc.intercept_)
print ("MAE value: {:.4f}".format(mae))
print ("MSE value: {:.4f}".format(mse))
print(" RMSE value : ".format(rmse))
print ("R2 Score value: {:.4f}".format(r2))
print ("Adjusted R2 Score value: {:.4f}".format(adjusted_r2))
# Out:
# Elastic Net Regression
# The regression Coefficient are :  [-0.60113986 -0.06215978 -0.          0.75962797  0.06867428  0.39291798]
# The Intercept  is :  32.26229508196721
# MAE value: 2.3394
# MSE value: 2.3394
#  RMSE value :
# R2 Score value: 0.4700
# Adjusted R2 Score value: 0.4112

# %% [markdown]
# #### Checking Assumptions:

# %%
# Linarity
plt.scatter(y_test,elsc_pred) 
plt.xlabel("Test Truth Data")
plt.ylabel("Test Predicted Data")
# Out:
# Text(0, 0.5, 'Test Predicted Data')

# %%
# residual distribution
residuals=y_test- elsc_pred
residuals
# Out:
# 64     1.789540
# 63     3.238607
# 55     2.459616
# 111   -3.503137
# 225   -1.006779
#          ...
# 116   -3.249047
# 33     1.640606
# 122    1.678592
# 161    1.708728
# 96    -2.542708
# Name: Temperature, Length: 61, dtype: float64

# %%
sns.displot(residuals,kind="kde")

# %%
# homoscedestacity
plt.scatter(elsc_pred,residuals)
plt.xlabel('predicted values')
plt.ylabel('Residuals')
sns.lineplot([-8,42],[0,0],color='blue')
# Out:
# <AxesSubplot:xlabel='predicted values', ylabel='Residuals'>

# %% [markdown]
# # THANK YOU
# prefformed by : Ankit Dubey
